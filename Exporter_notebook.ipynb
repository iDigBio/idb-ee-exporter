# %%
diff = sqlContext.read.parquet("/guoda/outputs/idigbio-20180414T023309-20180519T023311.parquet")

# %%
diff.count()
# Out:
# 193482

# %%
diff.printSchema()
# Out:
# root
#  |-- barcodevalue: string (nullable = true)
#  |-- basisofrecord: string (nullable = true)
#  |-- bed: string (nullable = true)
#  |-- canonicalname: string (nullable = true)
#  |-- catalognumber: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- collectioncode: string (nullable = true)
#  |-- collectionid: string (nullable = true)
#  |-- collectionname: string (nullable = true)
#  |-- collector: string (nullable = true)
#  |-- commonname: string (nullable = true)
#  |-- continent: string (nullable = true)
#  |-- coordinateuncertainty: float (nullable = true)
#  |-- country: string (nullable = true)
#  |-- countrycode: string (nullable = true)
#  |-- county: string (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- coreid: string (nullable = true)
#  |    |-- dc:rights: string (nullable = true)
#  |    |-- dcterms:accessRights: string (nullable = true)
#  |    |-- dcterms:bibliographicCitation: string (nullable = true)
#  |    |-- dcterms:language: string (nullable = true)
#  |    |-- dcterms:license: string (nullable = true)
#  |    |-- dcterms:modified: string (nullable = true)
#  |    |-- dcterms:references: string (nullable = true)
#  |    |-- dcterms:rights: string (nullable = true)
#  |    |-- dcterms:rightsHolder: string (nullable = true)
#  |    |-- dcterms:source: string (nullable = true)
#  |    |-- dcterms:type: string (nullable = true)
#  |    |-- dwc:VerbatimEventDate: string (nullable = true)
#  |    |-- dwc:acceptedNameUsage: string (nullable = true)
#  |    |-- dwc:accessRights: string (nullable = true)
#  |    |-- dwc:associatedMedia: string (nullable = true)
#  |    |-- dwc:associatedOccurrences: string (nullable = true)
#  |    |-- dwc:associatedOrganisms: string (nullable = true)
#  |    |-- dwc:associatedReferences: string (nullable = true)
#  |    |-- dwc:associatedSequences: string (nullable = true)
#  |    |-- dwc:associatedTaxa: string (nullable = true)
#  |    |-- dwc:basisOfRecord: string (nullable = true)
#  |    |-- dwc:bed: string (nullable = true)
#  |    |-- dwc:behavior: string (nullable = true)
#  |    |-- dwc:catalogNumber: string (nullable = true)
#  |    |-- dwc:class: string (nullable = true)
#  |    |-- dwc:classs: string (nullable = true)
#  |    |-- dwc:collectionCode: string (nullable = true)
#  |    |-- dwc:collectionID: string (nullable = true)
#  |    |-- dwc:continent: string (nullable = true)
#  |    |-- dwc:coordinatePrecision: string (nullable = true)
#  |    |-- dwc:coordinateUncertaintyInMeters: string (nullable = true)
#  |    |-- dwc:country: string (nullable = true)
#  |    |-- dwc:countryCode: string (nullable = true)
#  |    |-- dwc:county: string (nullable = true)
#  |    |-- dwc:dataGeneralizations: string (nullable = true)
#  |    |-- dwc:datasetID: string (nullable = true)
#  |    |-- dwc:datasetName: string (nullable = true)
#  |    |-- dwc:dateIdentified: string (nullable = true)
#  |    |-- dwc:day: string (nullable = true)
#  |    |-- dwc:decimalLatitude: string (nullable = true)
#  |    |-- dwc:decimalLongitude: string (nullable = true)
#  |    |-- dwc:disposition: string (nullable = true)
#  |    |-- dwc:dynamicProperties: string (nullable = true)
#  |    |-- dwc:earliestAgeOrLowestStage: string (nullable = true)
#  |    |-- dwc:earliestEonOrLowestEonothem: string (nullable = true)
#  |    |-- dwc:earliestEpochOrLowestSeries: string (nullable = true)
#  |    |-- dwc:earliestEraOrLowestErathem: string (nullable = true)
#  |    |-- dwc:earliestPeriodOrLowestSystem: string (nullable = true)
#  |    |-- dwc:endDayOfYear: string (nullable = true)
#  |    |-- dwc:establishmentMeans: string (nullable = true)
#  |    |-- dwc:eventDate: string (nullable = true)
#  |    |-- dwc:eventID: string (nullable = true)
#  |    |-- dwc:eventRemarks: string (nullable = true)
#  |    |-- dwc:eventTime: string (nullable = true)
#  |    |-- dwc:family: string (nullable = true)
#  |    |-- dwc:fieldNotes: string (nullable = true)
#  |    |-- dwc:fieldNumber: string (nullable = true)
#  |    |-- dwc:footprintSRS: string (nullable = true)
#  |    |-- dwc:footprintSpatialFit: string (nullable = true)
#  |    |-- dwc:footprintWKT: string (nullable = true)
#  |    |-- dwc:formation: string (nullable = true)
#  |    |-- dwc:genus: string (nullable = true)
#  |    |-- dwc:geodeticDatum: string (nullable = true)
#  |    |-- dwc:geologicalContextID: string (nullable = true)
#  |    |-- dwc:georeferenceProtocol: string (nullable = true)
#  |    |-- dwc:georeferenceRemarks: string (nullable = true)
#  |    |-- dwc:georeferenceSources: string (nullable = true)
#  |    |-- dwc:georeferenceVerificationStatus: string (nullable = true)
#  |    |-- dwc:georeferencedBy: string (nullable = true)
#  |    |-- dwc:georeferencedDate: string (nullable = true)
#  |    |-- dwc:group: string (nullable = true)
#  |    |-- dwc:habitat: string (nullable = true)
#  |    |-- dwc:higherClassification: string (nullable = true)
#  |    |-- dwc:higherGeography: string (nullable = true)
#  |    |-- dwc:higherGeographyID: string (nullable = true)
#  |    |-- dwc:highestBiostratigraphicZone: string (nullable = true)
#  |    |-- dwc:identificationID: string (nullable = true)
#  |    |-- dwc:identificationQualifier: string (nullable = true)
#  |    |-- dwc:identificationReferences: string (nullable = true)
#  |    |-- dwc:identificationRemarks: string (nullable = true)
#  |    |-- dwc:identificationVerificationStatus: string (nullable = true)
#  |    |-- dwc:identifiedBy: string (nullable = true)
#  |    |-- dwc:individualCount: string (nullable = true)
#  |    |-- dwc:informationWithheld: string (nullable = true)
#  |    |-- dwc:infraspecificEpithet: string (nullable = true)
#  |    |-- dwc:institutionCode: string (nullable = true)
#  |    |-- dwc:institutionID: string (nullable = true)
#  |    |-- dwc:island: string (nullable = true)
#  |    |-- dwc:islandGroup: string (nullable = true)
#  |    |-- dwc:kingdom: string (nullable = true)
#  |    |-- dwc:language: string (nullable = true)
#  |    |-- dwc:latestAgeOrHighestStage: string (nullable = true)
#  |    |-- dwc:latestEonOrHighestEonothem: string (nullable = true)
#  |    |-- dwc:latestEpochOrHighestSeries: string (nullable = true)
#  |    |-- dwc:latestEraOrHighestErathem: string (nullable = true)
#  |    |-- dwc:latestPeriodOrHighestSystem: string (nullable = true)
#  |    |-- dwc:lifeStage: string (nullable = true)
#  |    |-- dwc:lithostratigraphicTerms: string (nullable = true)
#  |    |-- dwc:locality: string (nullable = true)
#  |    |-- dwc:locationAccordingTo: string (nullable = true)
#  |    |-- dwc:locationID: string (nullable = true)
#  |    |-- dwc:locationRemarks: string (nullable = true)
#  |    |-- dwc:lowestBiostratigraphicZone: string (nullable = true)
#  |    |-- dwc:materialSampleID: string (nullable = true)
#  |    |-- dwc:maximumDepthInMeters: string (nullable = true)
#  |    |-- dwc:maximumElevationInMeters: string (nullable = true)
#  |    |-- dwc:member: string (nullable = true)
#  |    |-- dwc:minimumDepthInMeters: string (nullable = true)
#  |    |-- dwc:minimumElevationInMeters: string (nullable = true)
#  |    |-- dwc:modified: string (nullable = true)
#  |    |-- dwc:month: string (nullable = true)
#  |    |-- dwc:municipality: string (nullable = true)
#  |    |-- dwc:nameAccordingTo: string (nullable = true)
#  |    |-- dwc:nameAccordingToID: string (nullable = true)
#  |    |-- dwc:namePublishedIn: string (nullable = true)
#  |    |-- dwc:namePublishedInID: string (nullable = true)
#  |    |-- dwc:namePublishedInYear: string (nullable = true)
#  |    |-- dwc:nomenclaturalCode: string (nullable = true)
#  |    |-- dwc:nomenclaturalStatus: string (nullable = true)
#  |    |-- dwc:occurrenceDetails: string (nullable = true)
#  |    |-- dwc:occurrenceID: string (nullable = true)
#  |    |-- dwc:occurrenceRemarks: string (nullable = true)
#  |    |-- dwc:occurrenceStatus: string (nullable = true)
#  |    |-- dwc:order: string (nullable = true)
#  |    |-- dwc:organismID: string (nullable = true)
#  |    |-- dwc:organismName: string (nullable = true)
#  |    |-- dwc:organismQuantity: string (nullable = true)
#  |    |-- dwc:organismQuantityType: string (nullable = true)
#  |    |-- dwc:originalNameUsage: string (nullable = true)
#  |    |-- dwc:otherCatalogNumbers: string (nullable = true)
#  |    |-- dwc:ownerInstitutionCode: string (nullable = true)
#  |    |-- dwc:parentNameUsage: string (nullable = true)
#  |    |-- dwc:phylum: string (nullable = true)
#  |    |-- dwc:pointRadiusSpatialFit: string (nullable = true)
#  |    |-- dwc:preparations: string (nullable = true)
#  |    |-- dwc:previousIdentifications: string (nullable = true)
#  |    |-- dwc:recordNumber: string (nullable = true)
#  |    |-- dwc:recordedBy: string (nullable = true)
#  |    |-- dwc:reproductiveCondition: string (nullable = true)
#  |    |-- dwc:rights: string (nullable = true)
#  |    |-- dwc:rightsHolder: string (nullable = true)
#  |    |-- dwc:samplingEffort: string (nullable = true)
#  |    |-- dwc:samplingProtocol: string (nullable = true)
#  |    |-- dwc:scientificName: string (nullable = true)
#  |    |-- dwc:scientificNameAuthorship: string (nullable = true)
#  |    |-- dwc:scientificNameID: string (nullable = true)
#  |    |-- dwc:sex: string (nullable = true)
#  |    |-- dwc:specificEpithet: string (nullable = true)
#  |    |-- dwc:startDayOfYear: string (nullable = true)
#  |    |-- dwc:stateProvince: string (nullable = true)
#  |    |-- dwc:subgenus: string (nullable = true)
#  |    |-- dwc:taxonID: string (nullable = true)
#  |    |-- dwc:taxonRank: string (nullable = true)
#  |    |-- dwc:taxonRemarks: string (nullable = true)
#  |    |-- dwc:taxonomicStatus: string (nullable = true)
#  |    |-- dwc:typeStatus: string (nullable = true)
#  |    |-- dwc:verbatimCoordinateSystem: string (nullable = true)
#  |    |-- dwc:verbatimCoordinates: string (nullable = true)
#  |    |-- dwc:verbatimDepth: string (nullable = true)
#  |    |-- dwc:verbatimElevation: string (nullable = true)
#  |    |-- dwc:verbatimEventDate: string (nullable = true)
#  |    |-- dwc:verbatimLatitude: string (nullable = true)
#  |    |-- dwc:verbatimLocality: string (nullable = true)
#  |    |-- dwc:verbatimLongitude: string (nullable = true)
#  |    |-- dwc:verbatimSRS: string (nullable = true)
#  |    |-- dwc:verbatimTaxonRank: string (nullable = true)
#  |    |-- dwc:vernacularName: string (nullable = true)
#  |    |-- dwc:waterBody: string (nullable = true)
#  |    |-- dwc:year: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- idigbio:recordId: string (nullable = true)
#  |    |-- symbiota:recordEnteredBy: string (nullable = true)
#  |    |-- symbiota:verbatimScientificName: string (nullable = true)
#  |-- datasetid: string (nullable = true)
#  |-- datecollected: timestamp (nullable = true)
#  |-- datemodified: timestamp (nullable = true)
#  |-- dqs: float (nullable = true)
#  |-- earliestageorloweststage: string (nullable = true)
#  |-- earliesteonorlowesteonothem: string (nullable = true)
#  |-- earliestepochorlowestseries: string (nullable = true)
#  |-- earliesteraorlowesterathem: string (nullable = true)
#  |-- earliestperiodorlowestsystem: string (nullable = true)
#  |-- etag: string (nullable = true)
#  |-- eventdate: string (nullable = true)
#  |-- family: string (nullable = true)
#  |-- fieldnumber: string (nullable = true)
#  |-- formation: string (nullable = true)
#  |-- genus: string (nullable = true)
#  |-- geologicalcontextid: string (nullable = true)
#  |-- geopoint: struct (nullable = true)
#  |    |-- lat: double (nullable = true)
#  |    |-- lon: double (nullable = true)
#  |-- group: string (nullable = true)
#  |-- hasImage: boolean (nullable = true)
#  |-- hasMedia: boolean (nullable = true)
#  |-- highertaxon: string (nullable = true)
#  |-- highestbiostratigraphiczone: string (nullable = true)
#  |-- individualcount: float (nullable = true)
#  |-- infraspecificepithet: string (nullable = true)
#  |-- institutioncode: string (nullable = true)
#  |-- institutionid: string (nullable = true)
#  |-- institutionname: string (nullable = true)
#  |-- kingdom: string (nullable = true)
#  |-- latestageorhigheststage: string (nullable = true)
#  |-- latesteonorhighesteonothem: string (nullable = true)
#  |-- latestepochorhighestseries: string (nullable = true)
#  |-- latesteraorhighesterathem: string (nullable = true)
#  |-- latestperiodorhighestsystem: string (nullable = true)
#  |-- lithostratigraphicterms: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- lowestbiostratigraphiczone: string (nullable = true)
#  |-- maxdepth: float (nullable = true)
#  |-- maxelevation: float (nullable = true)
#  |-- member: string (nullable = true)
#  |-- mindepth: float (nullable = true)
#  |-- minelevation: float (nullable = true)
#  |-- municipality: string (nullable = true)
#  |-- occurrenceid: string (nullable = true)
#  |-- order: string (nullable = true)
#  |-- phylum: string (nullable = true)
#  |-- recordnumber: string (nullable = true)
#  |-- recordset: string (nullable = true)
#  |-- scientificname: string (nullable = true)
#  |-- specificepithet: string (nullable = true)
#  |-- startdayofyear: integer (nullable = true)
#  |-- stateprovince: string (nullable = true)
#  |-- taxonid: string (nullable = true)
#  |-- taxonomicstatus: string (nullable = true)
#  |-- taxonrank: string (nullable = true)
#  |-- typestatus: string (nullable = true)
#  |-- uuid: string (nullable = true)
#  |-- verbatimeventdate: string (nullable = true)
#  |-- verbatimlocality: string (nullable = true)
#  |-- version: integer (nullable = true)
#  |-- waterbody: string (nullable = true)
#  |-- op: string (nullable = true)

# %% [markdown]
# Can't write this structure out as a CSV, need to flatten it first. Dropping to SQL syntax will let us use string manipulation to construct the query.

# %%
sqlContext.registerDataFrameAsTable(diff, "diff")

# %%
(spark.sql("select collector, data.id, data.`dwc:year` as data_dwc_year from diff").show(3))
# Out:
# +--------------------+--------------------+-------------+
# |           collector|                  id|data_dwc_year|
# +--------------------+--------------------+-------------+
# |         m. a. faust|http://n2t.net/ar...|         2009|
# |                null|URI:catalog:ROM:B...|         null|
# |collector(s): ken...|http://arctos.dat...|         1981|
# +--------------------+--------------------+-------------+
# only showing top 3 rows

# %% [markdown]
# So to refer to values in struct columns, use a dot, to escape the :, use backticks. To do both, don't backtick the struct column name.
#
# Now we should be ok to iterate over columns and construct a list of things to select.
#
# Hey, there's examples! https://docs.databricks.com/spark/latest/spark-sql/complex-types.html None quite fit this case.
#
# Also, consider selectExpr() instead of full SQL.

# %%
for s in diff.schema:
    print(s.dataType)
# Out:
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# FloatType
# StringType
# StringType
# StringType
# StructType(List(StructField(coreid,StringType,true),StructField(dc:rights,StringType,true),StructField(dcterms:accessRights,StringType,true),StructField(dcterms:bibliographicCitation,StringType,true),StructField(dcterms:language,StringType,true),StructField(dcterms:license,StringType,true),StructField(dcterms:modified,StringType,true),StructField(dcterms:references,StringType,true),StructField(dcterms:rights,StringType,true),StructField(dcterms:rightsHolder,StringType,true),StructField(dcterms:source,StringType,true),StructField(dcterms:type,StringType,true),StructField(dwc:VerbatimEventDate,StringType,true),StructField(dwc:acceptedNameUsage,StringType,true),StructField(dwc:accessRights,StringType,true),StructField(dwc:associatedMedia,StringType,true),StructField(dwc:associatedOccurrences,StringType,true),StructField(dwc:associatedOrganisms,StringType,true),StructField(dwc:associatedReferences,StringType,true),StructField(dwc:associatedSequences,StringType,true),StructField(dwc:associatedTaxa,StringType,true),StructField(dwc:basisOfRecord,StringType,true),StructField(dwc:bed,StringType,true),StructField(dwc:behavior,StringType,true),StructField(dwc:catalogNumber,StringType,true),StructField(dwc:class,StringType,true),StructField(dwc:classs,StringType,true),StructField(dwc:collectionCode,StringType,true),StructField(dwc:collectionID,StringType,true),StructField(dwc:continent,StringType,true),StructField(dwc:coordinatePrecision,StringType,true),StructField(dwc:coordinateUncertaintyInMeters,StringType,true),StructField(dwc:country,StringType,true),StructField(dwc:countryCode,StringType,true),StructField(dwc:county,StringType,true),StructField(dwc:dataGeneralizations,StringType,true),StructField(dwc:datasetID,StringType,true),StructField(dwc:datasetName,StringType,true),StructField(dwc:dateIdentified,StringType,true),StructField(dwc:day,StringType,true),StructField(dwc:decimalLatitude,StringType,true),StructField(dwc:decimalLongitude,StringType,true),StructField(dwc:disposition,StringType,true),StructField(dwc:dynamicProperties,StringType,true),StructField(dwc:earliestAgeOrLowestStage,StringType,true),StructField(dwc:earliestEonOrLowestEonothem,StringType,true),StructField(dwc:earliestEpochOrLowestSeries,StringType,true),StructField(dwc:earliestEraOrLowestErathem,StringType,true),StructField(dwc:earliestPeriodOrLowestSystem,StringType,true),StructField(dwc:endDayOfYear,StringType,true),StructField(dwc:establishmentMeans,StringType,true),StructField(dwc:eventDate,StringType,true),StructField(dwc:eventID,StringType,true),StructField(dwc:eventRemarks,StringType,true),StructField(dwc:eventTime,StringType,true),StructField(dwc:family,StringType,true),StructField(dwc:fieldNotes,StringType,true),StructField(dwc:fieldNumber,StringType,true),StructField(dwc:footprintSRS,StringType,true),StructField(dwc:footprintSpatialFit,StringType,true),StructField(dwc:footprintWKT,StringType,true),StructField(dwc:formation,StringType,true),StructField(dwc:genus,StringType,true),StructField(dwc:geodeticDatum,StringType,true),StructField(dwc:geologicalContextID,StringType,true),StructField(dwc:georeferenceProtocol,StringType,true),StructField(dwc:georeferenceRemarks,StringType,true),StructField(dwc:georeferenceSources,StringType,true),StructField(dwc:georeferenceVerificationStatus,StringType,true),StructField(dwc:georeferencedBy,StringType,true),StructField(dwc:georeferencedDate,StringType,true),StructField(dwc:group,StringType,true),StructField(dwc:habitat,StringType,true),StructField(dwc:higherClassification,StringType,true),StructField(dwc:higherGeography,StringType,true),StructField(dwc:higherGeographyID,StringType,true),StructField(dwc:highestBiostratigraphicZone,StringType,true),StructField(dwc:identificationID,StringType,true),StructField(dwc:identificationQualifier,StringType,true),StructField(dwc:identificationReferences,StringType,true),StructField(dwc:identificationRemarks,StringType,true),StructField(dwc:identificationVerificationStatus,String ...
# StringType
# TimestampType
# TimestampType
# FloatType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StructType(List(StructField(lat,DoubleType,true),StructField(lon,DoubleType,true)))
# StringType
# BooleanType
# BooleanType
# StringType
# StringType
# FloatType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# FloatType
# FloatType
# StringType
# FloatType
# FloatType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# IntegerType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# StringType
# IntegerType
# StringType
# StringType

# %%
# Only deals with one layer of structs, could make recursive if we ever end 
# up with multiple levels of nesting

def easy_name(s):
    """Remove special characters in column names"""
    return s.replace(':', '_')

def escape_name(s):
    """Escape special characters in columns names"""
    return "`{0}`".format(s)


selects = []
for s in diff.schema:
    name = str(s.name)
    dataType = str(s.dataType)
    if "StructType" in str(s.dataType):
        struct_name = str(s.name)
        for f in s.dataType:
            name = str(f.name)
            selects.append("{0}.{1} as {0}_{2}".format(easy_name(struct_name), 
                                                       escape_name(name), 
                                                        easy_name(name)))
    else:
        selects.append("{0} as {1}".format(escape_name(name), easy_name(name)))
        pass

for s in selects:
    print(s)
# Out:
# `barcodevalue` as barcodevalue
# `basisofrecord` as basisofrecord
# `bed` as bed
# `canonicalname` as canonicalname
# `catalognumber` as catalognumber
# `class` as class
# `collectioncode` as collectioncode
# `collectionid` as collectionid
# `collectionname` as collectionname
# `collector` as collector
# `commonname` as commonname
# `continent` as continent
# `coordinateuncertainty` as coordinateuncertainty
# `country` as country
# `countrycode` as countrycode
# `county` as county
# data.`coreid` as data_coreid
# data.`dc:rights` as data_dc_rights
# data.`dcterms:accessRights` as data_dcterms_accessRights
# data.`dcterms:bibliographicCitation` as data_dcterms_bibliographicCitation
# data.`dcterms:language` as data_dcterms_language
# data.`dcterms:license` as data_dcterms_license
# data.`dcterms:modified` as data_dcterms_modified
# data.`dcterms:references` as data_dcterms_references
# data.`dcterms:rights` as data_dcterms_rights
# data.`dcterms:rightsHolder` as data_dcterms_rightsHolder
# data.`dcterms:source` as data_dcterms_source
# data.`dcterms:type` as data_dcterms_type
# data.`dwc:VerbatimEventDate` as data_dwc_VerbatimEventDate
# data.`dwc:acceptedNameUsage` as data_dwc_acceptedNameUsage
# data.`dwc:accessRights` as data_dwc_accessRights
# data.`dwc:associatedMedia` as data_dwc_associatedMedia
# data.`dwc:associatedOccurrences` as data_dwc_associatedOccurrences
# data.`dwc:associatedOrganisms` as data_dwc_associatedOrganisms
# data.`dwc:associatedReferences` as data_dwc_associatedReferences
# data.`dwc:associatedSequences` as data_dwc_associatedSequences
# data.`dwc:associatedTaxa` as data_dwc_associatedTaxa
# data.`dwc:basisOfRecord` as data_dwc_basisOfRecord
# data.`dwc:bed` as data_dwc_bed
# data.`dwc:behavior` as data_dwc_behavior
# data.`dwc:catalogNumber` as data_dwc_catalogNumber
# data.`dwc:class` as data_dwc_class
# data.`dwc:classs` as data_dwc_classs
# data.`dwc:collectionCode` as data_dwc_collectionCode
# data.`dwc:collectionID` as data_dwc_collectionID
# data.`dwc:continent` as data_dwc_continent
# data.`dwc:coordinatePrecision` as data_dwc_coordinatePrecision
# data.`dwc:coordinateUncertaintyInMeters` as data_dwc_coordinateUncertaintyInMeters
# data.`dwc:country` as data_dwc_country
# data.`dwc:countryCode` as data_dwc_countryCode
# data.`dwc:county` as data_dwc_county
# data.`dwc:dataGeneralizations` as data_dwc_dataGeneralizations
# data.`dwc:datasetID` as data_dwc_datasetID
# data.`dwc:datasetName` as data_dwc_datasetName
# data.`dwc:dateIdentified` as data_dwc_dateIdentified
# data.`dwc:day` as data_dwc_day
# data.`dwc:decimalLatitude` as data_dwc_decimalLatitude
# data.`dwc:decimalLongitude` as data_dwc_decimalLongitude
# data.`dwc:disposition` as data_dwc_disposition
# data.`dwc:dynamicProperties` as data_dwc_dynamicProperties
# data.`dwc:earliestAgeOrLowestStage` as data_dwc_earliestAgeOrLowestStage
# data.`dwc:earliestEonOrLowestEonothem` as data_dwc_earliestEonOrLowestEonothem
# data.`dwc:earliestEpochOrLowestSeries` as data_dwc_earliestEpochOrLowestSeries
# data.`dwc:earliestEraOrLowestErathem` as data_dwc_earliestEraOrLowestErathem
# data.`dwc:earliestPeriodOrLowestSystem` as data_dwc_earliestPeriodOrLowestSystem
# data.`dwc:endDayOfYear` as data_dwc_endDayOfYear
# data.`dwc:establishmentMeans` as data_dwc_establishmentMeans
# data.`dwc:eventDate` as data_dwc_eventDate
# data.`dwc:eventID` as data_dwc_eventID
# data.`dwc:eventRemarks` as data_dwc_eventRemarks
# data.`dwc:eventTime` as data_dwc_eventTime
# data.`dwc:family` as data_dwc_family
# data.`dwc:fieldNotes` as data_dwc_fieldNotes
# data.`dwc:fieldNumber` as data_dwc_fieldNumber
# data.`dwc:footprintSRS` as data_dwc_footprintSRS
# data.`dwc:footprintSpatialFit` as data_dwc_footprintSpatialFit
# data.`dwc:footprintWKT` as data_dwc_footprintWKT
# data.`dwc:formation` as data_dwc_formation
# data.`dwc:genus` as data_dwc_genus
# data.`dwc:geodeticDatum` as data_dwc_geodeticDatum
# data.`dwc:geologicalContextID` as data_dwc_geologicalContextID
# data.`dwc:georeferenceProtocol` as data_dwc_georeferenceProtocol
# data.`dwc:georeferenceRemarks` as data_dwc_georeferenceRemarks
# data.`dwc:georeferenceSources` as data_dwc_georeferenceSources
# data.`dwc:georeferenceVerificationStatus` as data_dwc_georeferenceVerificationStatus
# data.`dwc:georeferencedBy` as data_dwc_georeferencedBy
# data.`dwc:georeferencedDate` as data_dwc_georeferencedDate
# data.`dwc:group` as data_dwc_group
# data.`dwc:habitat` as data_dwc_habitat
# data.`dwc:higherClassification` as data_dwc_higherClassification
# data.`dwc:higherGeography` as data_dwc_higherGeography
# data.`dwc:higherGeographyID` as data_dwc_higherGeographyID
# data.`dwc:highestBiostratigraphicZone` as data_dwc_highestBiostratigraphicZone
# data.`dwc:identificationID` as data_dwc_identificationID
# data.`dwc:identificationQualifier` as data_dwc_identificationQualifier
# data.`dwc:identificationReferences` as data_dwc_identificationReferences
# data.`dwc:identificationRemarks` as data_dwc_identificationRemarks
# data.`dwc:identificationVerificationStatus` as data_dwc_identificationVerificationStatus
# data.`dwc:identifiedBy` as data_dwc_identifiedBy
# data.`dwc:individualCount` as data_dwc_individualCount
# data.`dwc:informationWithheld` as data_dwc_informationWithheld
# data.`dwc:infraspecificEpithet` as data_dwc_infraspecificEpithet
# data.`dwc:institutionCode` as data_dwc_institutionCode
# data.`dwc:institutionID` as data_dwc_institutionID
# data.`dwc:island` as data_dwc_island
# data.`dwc:islandGroup` as data_dwc_islandGroup
# data.`dwc:kingdom` as data_dwc_kingdom
# data.`dwc:language` as data_dwc_language
# data.`dwc:latestAgeOrHighestStage` as data_dwc_latestAgeOrHighestStage
# data.`dwc:latestEonOrHighestEonothem` as data_dwc_latestEonOrHighestEonothem
# data.`dwc:latestEpochOrHighestSeries` as data_dwc_latestEpochOrHighestSeries
# data.`dwc:latestEraOrHighestErathem` as data_dwc_latestEraOrHighestErathem
# data.`dwc:latestPeriodOrHighestSystem` as data_dwc_latestPeriodOrHighestSystem
# data.`dwc:lifeStage` as data_dwc_lifeStage
# data.`dwc:lithostratigraphicTerms` as data_dwc_lithostratigraphicTerms
# data.`dwc:locality` as data_dwc_locality
# data.`dwc:locationAccordingTo` as data_dwc_locationAccordingTo
# data.`dwc:locationID` as data_dwc_locationID
# data.`dwc:locationRemarks` as data_dwc_locationRemarks
# data.`dwc:lowestBiostratigraphicZone` as data_dwc_lowestBiostratigraphicZone
# data.`dwc:materialSampleID` as data_dwc_materialSampleID
# data.`dwc:maximumDepthInMeters` as data_dwc_maximumDepthInMeters
# data.`dwc:maximumElevationInMeters` as data_dwc_maximumElevationInMeters
# data.`dwc:member` as data_dwc_member
# data.`dwc:minimumDepthInMeters` as data_dwc_minimumDepthInMeters
# data.`dwc:minimumElevationInMeters` as data_dwc_minimumElevationInMeters
# data.`dwc:modified` as data_dwc_modified
# data.`dwc:month` as data_dwc_month
# data.`dwc:municipality` as data_dwc_municipality
# data.`dwc:nameAccordingTo` as data_dwc_nameAccordingTo
# data.`dwc:nameAccordingToID` as data_dwc_nameAccordingToID
# data.`dwc:namePublishedIn` as data_dwc_namePublishedIn
# data.`dwc:namePublishedInID` as data_dwc_namePublishedInID
# data.`dwc:namePublishedInYear` as data_dwc_namePublishedInYear
# data.`dwc:nomenclaturalCode` as data_dwc_nomenclaturalCode
# data.`dwc:nomenclaturalStatus` as data_dwc_nomenclaturalStatus
# data.`dwc:occurrenceDetails` as data_dwc_occurrenceDetails
# data.`dwc:occurrenceID` as data_dwc_occurrenceID
# data.`dwc:occurrenceRemarks` as data_dwc_occurrenceRemarks
# data.`dwc:occurrenceStatus` as data_dwc_occurrenceStatus
# data.`dwc:order` as data_dwc_order
# data.`dwc:organismID` as data_dwc_organismID
# data.`dwc:organismName` as data_dwc_organismName
# data.`dwc:organismQuantity` as data_dwc_organismQuantity
# data.`dwc:organismQuantityType` as data_dwc_organismQuantityType
# data.`dwc:originalNameUsage` as data_dwc_originalNameUsage
# data.`dwc:otherCatalogNumbers` as data_dwc_otherCatalogNumbers
# data.`dwc:ownerInstitutionCode` as data_dwc_ownerInstitutionCode
# data.`dwc:parentNameUsage` as data_dwc_parentNameUsage
# data.`dwc:phylum` as data_dwc_phylum
# data.`dwc:pointRadiusSpatialFit` as data_dwc_pointRadiusSpatialFit
# data.`dwc:preparations` as data_dwc_preparations
# data.`dwc:previousIdentifications` as data_dwc_previousIdentifications
# data.`dwc:recordNumber` as data_dwc_recordNumber
# data.`dwc:recordedBy` as data_dwc_recordedBy
# data.`dwc:reproductiveCondition` as data_dwc_reproductiveCondition
# data.`dwc:rights` as data_dwc_rights
# data.`dwc:rightsHolder` as data_dwc_rightsHolder
# data.`dwc:samplingEffort` as data_dwc_samplingEffort
# data.`dwc:samplingProtocol` as data_dwc_samplingProtocol
# data.`dwc:scientificName` as data_dwc_scientificName
# data.`dwc:scientificNameAuthorship` as data_dwc_scientificNameAuthorship
# data.`dwc:scientificNameID` as data_dwc_scientificNameID
# data.`dwc:sex` as data_dwc_sex
# data.`dwc:specificEpithet` as data_dwc_specificEpithet
# data.`dwc:startDayOfYear` as data_dwc_startDayOfYear
# data.`dwc:stateProvince` as data_dwc_stateProvince
# data.`dwc:subgenus` as data_dwc_subgenus
# data.`dwc:taxonID` as data_dwc_taxonID
# data.`dwc:taxonRank` as data_dwc_taxonRank
# data.`dwc:taxonRemarks` as data_dwc_taxonRemarks
# data.`dwc:taxonomicStatus` as data_dwc_taxonomicStatus
# data.`dwc:typeStatus` as data_dwc_typeStatus
# data.`dwc:verbatimCoordinateSystem` as data_dwc_verbatimCoordinateSystem
# data.`dwc:verbatimCoordinates` as data_dwc_verbatimCoordinates
# data.`dwc:verbatimDepth` as data_dwc_verbatimDepth
# data.`dwc:verbatimElevation` as data_dwc_verbatimElevation
# data.`dwc:verbatimEventDate` as data_dwc_verbatimEventDate
# data.`dwc:verbatimLatitude` as data_dwc_verbatimLatitude
# data.`dwc:verbatimLocality` as data_dwc_verbatimLocality
# data.`dwc:verbatimLongitude` as data_dwc_verbatimLongitude
# data.`dwc:verbatimSRS` as data_dwc_verbatimSRS
# data.`dwc:verbatimTaxonRank` as data_dwc_verbatimTaxonRank
# data.`dwc:vernacularName` as data_dwc_vernacularName
# data.`dwc:waterBody` as data_dwc_waterBody
# data.`dwc:year` as data_dwc_year
# data.`id` as data_id
# data.`idigbio:recordId` as data_idigbio_recordId
# data.`symbiota:recordEnteredBy` as data_symbiota_recordEnteredBy
# data.`symbiota:verbatimScientificName` as data_symbiota_verbatimScientificName
# `datasetid` as datasetid
# `datecollected` as datecollected
# `datemodified` as datemodified
# `dqs` as dqs
# `earliestageorloweststage` as earliestageorloweststage
# `earliesteonorlowesteonothem` as earliesteonorlowesteonothem
# `earliestepochorlowestseries` as earliestepochorlowestseries
# `earliesteraorlowesterathem` as earliesteraorlowesterathem
# `earliestperiodorlowestsystem` as earliestperiodorlowestsystem
# `etag` as etag
# `eventdate` as eventdate
# `family` as family
# `fieldnumber` as fieldnumber
# `formation` as formation
# `genus` as genus
# `geologicalcontextid` as geologicalcontextid
# geopoint.`lat` as geopoint_lat
# geopoint.`lon` as geopoint_lon
# `group` as group
# `hasImage` as hasImage
# `hasMedia` as hasMedia
# `highertaxon` as highertaxon
# `highestbiostratigraphiczone` as highestbiostratigraphiczone
# `individualcount` as individualcount
# `infraspecificepithet` as infraspecificepithet
# `institutioncode` as institutioncode
# `institutionid` as institutionid
# `institutionname` as institutionname
# `kingdom` as kingdom
# `latestageorhigheststage` as latestageorhigheststage
# `latesteonorhighesteonothem` as latesteonorhighesteonothem
# `latestepochorhighestseries` as latestepochorhighestseries
# `latesteraorhighesterathem` as latesteraorhighesterathem
# `latestperiodorhighestsystem` as latestperiodorhighestsystem
# `lithostratigraphicterms` as lithostratigraphicterms
# `locality` as locality
# `lowestbiostratigraphiczone` as lowestbiostratigraphiczone
# `maxdepth` as maxdepth
# `maxelevation` as maxelevation
# `member` as member
# `mindepth` as mindepth
# `minelevation` as minelevation
# `municipality` as municipality
# `occurrenceid` as occurrenceid
# `order` as order
# `phylum` as phylum
# `recordnumber` as recordnumber
# `recordset` as recordset
# `scientificname` as scientificname
# `specificepithet` as specificepithet
# `startdayofyear` as startdayofyear
# `stateprovince` as stateprovince
# `taxonid` as taxonid
# `taxonomicstatus` as taxonomicstatus
# `taxonrank` as taxonrank
# `typestatus` as typestatus
# `uuid` as uuid
# `verbatimeventdate` as verbatimeventdate
# `verbatimlocality` as verbatimlocality
# `version` as version
# `waterbody` as waterbody
# `op` as op

# %%
# A cool approach found on line but explode doesn't do structs, only array and map
#from pyspark.sql.functions import explode, first, col, monotonically_increasing_id
#long = (diff
#   .withColumn("id", monotonically_increasing_id())
#   .select("id", explode("data").alias("col"))
#   .select("id", "col.*"))
#long.show(10, truncate=False)

# %% [markdown]
# Now we have a list of things that we can select directly to flatten our dataframe.
#
# Have to turn on column case sensativity to deal with multiple verbatimEventDate capitalizations. See https://redmine.idigbio.org/issues/2760

# %%
sqlContext.sql('set spark.sql.caseSensitive=true')
# Out:
# DataFrame[key: string, value: string]

# %%
flat = diff.selectExpr(selects)

# %%
flat.show(1, truncate=False)
# Out:
# +------------+-----------------+----+-------------+-------------+-----------+--------------+------------+--------------+-----------+----------+-------------+---------------------+-------------+-----------+------+-----------+--------------+-------------------------+----------------------------------+---------------------+--------------------+---------------------+-----------------------+-------------------+-------------------------+-------------------+-----------------+--------------------------+--------------------------+---------------------+------------------------+------------------------------+----------------------------+-----------------------------+----------------------------+-----------------------+----------------------+------------+-----------------+----------------------+--------------+---------------+-----------------------+---------------------+------------------+----------------------------+--------------------------------------+----------------+--------------------+---------------+----------------------------+------------------+--------------------+-----------------------+------------+------------------------+-------------------------+--------------------+--------------------------+---------------------------------+------------------------------------+------------------------------------+-----------------------------------+-------------------------------------+---------------------+---------------------------+------------------+----------------+---------------------+------------------+---------------+-------------------+--------------------+---------------------+----------------------------+---------------------+------------------+--------------+----------------------+----------------------------+-----------------------------+----------------------------+----------------------------+---------------------------------------+------------------------+--------------------------+--------------+----------------+-------------------------------------+---------------------------------------------------------------+--------------------------+------------------------------------+-------------------------+--------------------------------+---------------------------------+------------------------------+-----------------------------------------+---------------------+------------------------+----------------------------+-----------------------------+------------------------+-----------------------------------------------+---------------+--------------------+----------------+-----------------+--------------------------------+-----------------------------------+-----------------------------------+----------------------------------+------------------------------------+------------------+--------------------------------+-----------------------------+----------------------------+-------------------+------------------------+-----------------------------------+-------------------------+-----------------------------+---------------------------------+---------------+-----------------------------+---------------------------------+-----------------+--------------+---------------------+------------------------+--------------------------+------------------------+--------------------------+----------------------------+--------------------------+----------------------------+--------------------------+---------------------------------------------------------------+--------------------------+-------------------------+--------------+-------------------+---------------------+-------------------------+-----------------------------+--------------------------+----------------------------+-----------------------------+------------------------+---------------+------------------------------+---------------------+--------------------------------+---------------------+-------------------+------------------------------+---------------+---------------------+-----------------------+-------------------------+-----------------------+------------------------- ...
# |barcodevalue|basisofrecord    |bed |canonicalname|catalognumber|class      |collectioncode|collectionid|collectionname|collector  |commonname|continent    |coordinateuncertainty|country      |countrycode|county|data_coreid|data_dc_rights|data_dcterms_accessRights|data_dcterms_bibliographicCitation|data_dcterms_language|data_dcterms_license|data_dcterms_modified|data_dcterms_references|data_dcterms_rights|data_dcterms_rightsHolder|data_dcterms_source|data_dcterms_type|data_dwc_VerbatimEventDate|data_dwc_acceptedNameUsage|data_dwc_accessRights|data_dwc_associatedMedia|data_dwc_associatedOccurrences|data_dwc_associatedOrganisms|data_dwc_associatedReferences|data_dwc_associatedSequences|data_dwc_associatedTaxa|data_dwc_basisOfRecord|data_dwc_bed|data_dwc_behavior|data_dwc_catalogNumber|data_dwc_class|data_dwc_classs|data_dwc_collectionCode|data_dwc_collectionID|data_dwc_continent|data_dwc_coordinatePrecision|data_dwc_coordinateUncertaintyInMeters|data_dwc_country|data_dwc_countryCode|data_dwc_county|data_dwc_dataGeneralizations|data_dwc_datasetID|data_dwc_datasetName|data_dwc_dateIdentified|data_dwc_day|data_dwc_decimalLatitude|data_dwc_decimalLongitude|data_dwc_disposition|data_dwc_dynamicProperties|data_dwc_earliestAgeOrLowestStage|data_dwc_earliestEonOrLowestEonothem|data_dwc_earliestEpochOrLowestSeries|data_dwc_earliestEraOrLowestErathem|data_dwc_earliestPeriodOrLowestSystem|data_dwc_endDayOfYear|data_dwc_establishmentMeans|data_dwc_eventDate|data_dwc_eventID|data_dwc_eventRemarks|data_dwc_eventTime|data_dwc_family|data_dwc_fieldNotes|data_dwc_fieldNumber|data_dwc_footprintSRS|data_dwc_footprintSpatialFit|data_dwc_footprintWKT|data_dwc_formation|data_dwc_genus|data_dwc_geodeticDatum|data_dwc_geologicalContextID|data_dwc_georeferenceProtocol|data_dwc_georeferenceRemarks|data_dwc_georeferenceSources|data_dwc_georeferenceVerificationStatus|data_dwc_georeferencedBy|data_dwc_georeferencedDate|data_dwc_group|data_dwc_habitat|data_dwc_higherClassification        |data_dwc_higherGeography                                       |data_dwc_higherGeographyID|data_dwc_highestBiostratigraphicZone|data_dwc_identificationID|data_dwc_identificationQualifier|data_dwc_identificationReferences|data_dwc_identificationRemarks|data_dwc_identificationVerificationStatus|data_dwc_identifiedBy|data_dwc_individualCount|data_dwc_informationWithheld|data_dwc_infraspecificEpithet|data_dwc_institutionCode|data_dwc_institutionID                         |data_dwc_island|data_dwc_islandGroup|data_dwc_kingdom|data_dwc_language|data_dwc_latestAgeOrHighestStage|data_dwc_latestEonOrHighestEonothem|data_dwc_latestEpochOrHighestSeries|data_dwc_latestEraOrHighestErathem|data_dwc_latestPeriodOrHighestSystem|data_dwc_lifeStage|data_dwc_lithostratigraphicTerms|data_dwc_locality            |data_dwc_locationAccordingTo|data_dwc_locationID|data_dwc_locationRemarks|data_dwc_lowestBiostratigraphicZone|data_dwc_materialSampleID|data_dwc_maximumDepthInMeters|data_dwc_maximumElevationInMeters|data_dwc_member|data_dwc_minimumDepthInMeters|data_dwc_minimumElevationInMeters|data_dwc_modified|data_dwc_month|data_dwc_municipality|data_dwc_nameAccordingTo|data_dwc_nameAccordingToID|data_dwc_namePublishedIn|data_dwc_namePublishedInID|data_dwc_namePublishedInYear|data_dwc_nomenclaturalCode|data_dwc_nomenclaturalStatus|data_dwc_occurrenceDetails|data_dwc_occurrenceID                                          |data_dwc_occurrenceRemarks|data_dwc_occurrenceStatus|data_dwc_order|data_dwc_organismID|data_dwc_organismName|data_dwc_organismQuantity|data_dwc_organismQuantityType|data_dwc_originalNameUsage|data_dwc_otherCatalogNumbers|data_dwc_ownerInstitutionCode|data_dwc_parentNameUsage|data_dwc_phylum|data_dwc_pointRadiusSpatialFit|data_dwc_preparations|data_dwc_previousIdentifications|data_dwc_recordNumber|data_dwc_recordedBy|data_dwc_reproductiveCondition|data_dwc_rights|data_dwc_rightsHolder|data_dwc_samplingEffort|data_dwc_samplingProtocol|data_dwc_scientificName|data_dwc_scientificNameAu ...
# +------------+-----------------+----+-------------+-------------+-----------+--------------+------------+--------------+-----------+----------+-------------+---------------------+-------------+-----------+------+-----------+--------------+-------------------------+----------------------------------+---------------------+--------------------+---------------------+-----------------------+-------------------+-------------------------+-------------------+-----------------+--------------------------+--------------------------+---------------------+------------------------+------------------------------+----------------------------+-----------------------------+----------------------------+-----------------------+----------------------+------------+-----------------+----------------------+--------------+---------------+-----------------------+---------------------+------------------+----------------------------+--------------------------------------+----------------+--------------------+---------------+----------------------------+------------------+--------------------+-----------------------+------------+------------------------+-------------------------+--------------------+--------------------------+---------------------------------+------------------------------------+------------------------------------+-----------------------------------+-------------------------------------+---------------------+---------------------------+------------------+----------------+---------------------+------------------+---------------+-------------------+--------------------+---------------------+----------------------------+---------------------+------------------+--------------+----------------------+----------------------------+-----------------------------+----------------------------+----------------------------+---------------------------------------+------------------------+--------------------------+--------------+----------------+-------------------------------------+---------------------------------------------------------------+--------------------------+------------------------------------+-------------------------+--------------------------------+---------------------------------+------------------------------+-----------------------------------------+---------------------+------------------------+----------------------------+-----------------------------+------------------------+-----------------------------------------------+---------------+--------------------+----------------+-----------------+--------------------------------+-----------------------------------+-----------------------------------+----------------------------------+------------------------------------+------------------+--------------------------------+-----------------------------+----------------------------+-------------------+------------------------+-----------------------------------+-------------------------+-----------------------------+---------------------------------+---------------+-----------------------------+---------------------------------+-----------------+--------------+---------------------+------------------------+--------------------------+------------------------+--------------------------+----------------------------+--------------------------+----------------------------+--------------------------+---------------------------------------------------------------+--------------------------+-------------------------+--------------+-------------------+---------------------+-------------------------+-----------------------------+--------------------------+----------------------------+-----------------------------+------------------------+---------------+------------------------------+---------------------+--------------------------------+---------------------+-------------------+------------------------------+---------------+---------------------+-----------------------+-------------------------+-----------------------+------------------------- ...
# |null        |preservedspecimen|null|null         |wet lot -3088|dinophyceae|botany        |null        |null          |m. a. faust|null      |north america|null                 |united states|usa        |null  |null       |null          |null                     |null                              |null                 |null                |null                 |null                   |null               |null                     |null               |PhysicalObject   |null                      |null                      |null                 |null                    |null                          |null                        |null                         |null                        |null                   |PreservedSpecimen     |null        |null             |wet lot -3088         |Dinophyceae   |null           |Botany                 |null                 |North America     |null                        |null                                  |United States   |null                |null           |null                        |null              |null                |null                   |15          |null                    |null                     |null                |null                      |null                             |null                                |null                                |null                               |null                                 |196                  |null                       |null              |null            |null                 |null              |null           |null               |null                |null                 |null                        |null                 |null              |Indet.        |null                  |null                        |null                         |null                        |null                        |null                                   |null                    |null                      |null          |plankton        |Protista, Dinoflagellata, Dinophyceae|North America, North Atlantic Ocean, Gulf Stream, United States|null                      |null                                |null                     |null                            |null                             |null                          |null                                     |null                 |1                       |null                        |null                         |US                      |http://biocol.org/urn:lsid:biocol.org:col:34871|null           |null                |Protista        |null             |null                            |null                               |null                               |null                              |null                                |null              |null                            |20 Miles off Ft. Pierce Inlet|null                        |null               |null                    |null                               |null                     |null                         |null                             |null           |1                            |null                             |null             |7             |null                 |null                    |null                      |null                    |null                      |null                        |null                      |null                        |null                      |http://n2t.net/ark:/65665/3f30fa9a3-60f8-4c92-b739-71e211ba9068|null                      |null                     |null          |null               |null                 |null                     |null                         |null                      |null                        |null                         |null                    |Dinoflagellata |null                          |Wet lot              |null                            |4025-2009            |M. A. Faust        |null                          |null           |null                 |null                   |null                     |Indet. sp.             |null                      ...
# +------------+-----------------+----+-------------+-------------+-----------+--------------+------------+--------------+-----------+----------+-------------+---------------------+-------------+-----------+------+-----------+--------------+-------------------------+----------------------------------+---------------------+--------------------+---------------------+-----------------------+-------------------+-------------------------+-------------------+-----------------+--------------------------+--------------------------+---------------------+------------------------+------------------------------+----------------------------+-----------------------------+----------------------------+-----------------------+----------------------+------------+-----------------+----------------------+--------------+---------------+-----------------------+---------------------+------------------+----------------------------+--------------------------------------+----------------+--------------------+---------------+----------------------------+------------------+--------------------+-----------------------+------------+------------------------+-------------------------+--------------------+--------------------------+---------------------------------+------------------------------------+------------------------------------+-----------------------------------+-------------------------------------+---------------------+---------------------------+------------------+----------------+---------------------+------------------+---------------+-------------------+--------------------+---------------------+----------------------------+---------------------+------------------+--------------+----------------------+----------------------------+-----------------------------+----------------------------+----------------------------+---------------------------------------+------------------------+--------------------------+--------------+----------------+-------------------------------------+---------------------------------------------------------------+--------------------------+------------------------------------+-------------------------+--------------------------------+---------------------------------+------------------------------+-----------------------------------------+---------------------+------------------------+----------------------------+-----------------------------+------------------------+-----------------------------------------------+---------------+--------------------+----------------+-----------------+--------------------------------+-----------------------------------+-----------------------------------+----------------------------------+------------------------------------+------------------+--------------------------------+-----------------------------+----------------------------+-------------------+------------------------+-----------------------------------+-------------------------+-----------------------------+---------------------------------+---------------+-----------------------------+---------------------------------+-----------------+--------------+---------------------+------------------------+--------------------------+------------------------+--------------------------+----------------------------+--------------------------+----------------------------+--------------------------+---------------------------------------------------------------+--------------------------+-------------------------+--------------+-------------------+---------------------+-------------------------+-----------------------------+--------------------------+----------------------------+-----------------------------+------------------------+---------------+------------------------------+---------------------+--------------------------------+---------------------+-------------------+------------------------------+---------------+---------------------+-----------------------+-------------------------+-----------------------+------------------------- ...
# only showing top 1 row

# %%
flat.printSchema()
# Out:
# root
#  |-- barcodevalue: string (nullable = true)
#  |-- basisofrecord: string (nullable = true)
#  |-- bed: string (nullable = true)
#  |-- canonicalname: string (nullable = true)
#  |-- catalognumber: string (nullable = true)
#  |-- class: string (nullable = true)
#  |-- collectioncode: string (nullable = true)
#  |-- collectionid: string (nullable = true)
#  |-- collectionname: string (nullable = true)
#  |-- collector: string (nullable = true)
#  |-- commonname: string (nullable = true)
#  |-- continent: string (nullable = true)
#  |-- coordinateuncertainty: float (nullable = true)
#  |-- country: string (nullable = true)
#  |-- countrycode: string (nullable = true)
#  |-- county: string (nullable = true)
#  |-- data_coreid: string (nullable = true)
#  |-- data_dc_rights: string (nullable = true)
#  |-- data_dcterms_accessRights: string (nullable = true)
#  |-- data_dcterms_bibliographicCitation: string (nullable = true)
#  |-- data_dcterms_language: string (nullable = true)
#  |-- data_dcterms_license: string (nullable = true)
#  |-- data_dcterms_modified: string (nullable = true)
#  |-- data_dcterms_references: string (nullable = true)
#  |-- data_dcterms_rights: string (nullable = true)
#  |-- data_dcterms_rightsHolder: string (nullable = true)
#  |-- data_dcterms_source: string (nullable = true)
#  |-- data_dcterms_type: string (nullable = true)
#  |-- data_dwc_VerbatimEventDate: string (nullable = true)
#  |-- data_dwc_acceptedNameUsage: string (nullable = true)
#  |-- data_dwc_accessRights: string (nullable = true)
#  |-- data_dwc_associatedMedia: string (nullable = true)
#  |-- data_dwc_associatedOccurrences: string (nullable = true)
#  |-- data_dwc_associatedOrganisms: string (nullable = true)
#  |-- data_dwc_associatedReferences: string (nullable = true)
#  |-- data_dwc_associatedSequences: string (nullable = true)
#  |-- data_dwc_associatedTaxa: string (nullable = true)
#  |-- data_dwc_basisOfRecord: string (nullable = true)
#  |-- data_dwc_bed: string (nullable = true)
#  |-- data_dwc_behavior: string (nullable = true)
#  |-- data_dwc_catalogNumber: string (nullable = true)
#  |-- data_dwc_class: string (nullable = true)
#  |-- data_dwc_classs: string (nullable = true)
#  |-- data_dwc_collectionCode: string (nullable = true)
#  |-- data_dwc_collectionID: string (nullable = true)
#  |-- data_dwc_continent: string (nullable = true)
#  |-- data_dwc_coordinatePrecision: string (nullable = true)
#  |-- data_dwc_coordinateUncertaintyInMeters: string (nullable = true)
#  |-- data_dwc_country: string (nullable = true)
#  |-- data_dwc_countryCode: string (nullable = true)
#  |-- data_dwc_county: string (nullable = true)
#  |-- data_dwc_dataGeneralizations: string (nullable = true)
#  |-- data_dwc_datasetID: string (nullable = true)
#  |-- data_dwc_datasetName: string (nullable = true)
#  |-- data_dwc_dateIdentified: string (nullable = true)
#  |-- data_dwc_day: string (nullable = true)
#  |-- data_dwc_decimalLatitude: string (nullable = true)
#  |-- data_dwc_decimalLongitude: string (nullable = true)
#  |-- data_dwc_disposition: string (nullable = true)
#  |-- data_dwc_dynamicProperties: string (nullable = true)
#  |-- data_dwc_earliestAgeOrLowestStage: string (nullable = true)
#  |-- data_dwc_earliestEonOrLowestEonothem: string (nullable = true)
#  |-- data_dwc_earliestEpochOrLowestSeries: string (nullable = true)
#  |-- data_dwc_earliestEraOrLowestErathem: string (nullable = true)
#  |-- data_dwc_earliestPeriodOrLowestSystem: string (nullable = true)
#  |-- data_dwc_endDayOfYear: string (nullable = true)
#  |-- data_dwc_establishmentMeans: string (nullable = true)
#  |-- data_dwc_eventDate: string (nullable = true)
#  |-- data_dwc_eventID: string (nullable = true)
#  |-- data_dwc_eventRemarks: string (nullable = true)
#  |-- data_dwc_eventTime: string (nullable = true)
#  |-- data_dwc_family: string (nullable = true)
#  |-- data_dwc_fieldNotes: string (nullable = true)
#  |-- data_dwc_fieldNumber: string (nullable = true)
#  |-- data_dwc_footprintSRS: string (nullable = true)
#  |-- data_dwc_footprintSpatialFit: string (nullable = true)
#  |-- data_dwc_footprintWKT: string (nullable = true)
#  |-- data_dwc_formation: string (nullable = true)
#  |-- data_dwc_genus: string (nullable = true)
#  |-- data_dwc_geodeticDatum: string (nullable = true)
#  |-- data_dwc_geologicalContextID: string (nullable = true)
#  |-- data_dwc_georeferenceProtocol: string (nullable = true)
#  |-- data_dwc_georeferenceRemarks: string (nullable = true)
#  |-- data_dwc_georeferenceSources: string (nullable = true)
#  |-- data_dwc_georeferenceVerificationStatus: string (nullable = true)
#  |-- data_dwc_georeferencedBy: string (nullable = true)
#  |-- data_dwc_georeferencedDate: string (nullable = true)
#  |-- data_dwc_group: string (nullable = true)
#  |-- data_dwc_habitat: string (nullable = true)
#  |-- data_dwc_higherClassification: string (nullable = true)
#  |-- data_dwc_higherGeography: string (nullable = true)
#  |-- data_dwc_higherGeographyID: string (nullable = true)
#  |-- data_dwc_highestBiostratigraphicZone: string (nullable = true)
#  |-- data_dwc_identificationID: string (nullable = true)
#  |-- data_dwc_identificationQualifier: string (nullable = true)
#  |-- data_dwc_identificationReferences: string (nullable = true)
#  |-- data_dwc_identificationRemarks: string (nullable = true)
#  |-- data_dwc_identificationVerificationStatus: string (nullable = true)
#  |-- data_dwc_identifiedBy: string (nullable = true)
#  |-- data_dwc_individualCount: string (nullable = true)
#  |-- data_dwc_informationWithheld: string (nullable = true)
#  |-- data_dwc_infraspecificEpithet: string (nullable = true)
#  |-- data_dwc_institutionCode: string (nullable = true)
#  |-- data_dwc_institutionID: string (nullable = true)
#  |-- data_dwc_island: string (nullable = true)
#  |-- data_dwc_islandGroup: string (nullable = true)
#  |-- data_dwc_kingdom: string (nullable = true)
#  |-- data_dwc_language: string (nullable = true)
#  |-- data_dwc_latestAgeOrHighestStage: string (nullable = true)
#  |-- data_dwc_latestEonOrHighestEonothem: string (nullable = true)
#  |-- data_dwc_latestEpochOrHighestSeries: string (nullable = true)
#  |-- data_dwc_latestEraOrHighestErathem: string (nullable = true)
#  |-- data_dwc_latestPeriodOrHighestSystem: string (nullable = true)
#  |-- data_dwc_lifeStage: string (nullable = true)
#  |-- data_dwc_lithostratigraphicTerms: string (nullable = true)
#  |-- data_dwc_locality: string (nullable = true)
#  |-- data_dwc_locationAccordingTo: string (nullable = true)
#  |-- data_dwc_locationID: string (nullable = true)
#  |-- data_dwc_locationRemarks: string (nullable = true)
#  |-- data_dwc_lowestBiostratigraphicZone: string (nullable = true)
#  |-- data_dwc_materialSampleID: string (nullable = true)
#  |-- data_dwc_maximumDepthInMeters: string (nullable = true)
#  |-- data_dwc_maximumElevationInMeters: string (nullable = true)
#  |-- data_dwc_member: string (nullable = true)
#  |-- data_dwc_minimumDepthInMeters: string (nullable = true)
#  |-- data_dwc_minimumElevationInMeters: string (nullable = true)
#  |-- data_dwc_modified: string (nullable = true)
#  |-- data_dwc_month: string (nullable = true)
#  |-- data_dwc_municipality: string (nullable = true)
#  |-- data_dwc_nameAccordingTo: string (nullable = true)
#  |-- data_dwc_nameAccordingToID: string (nullable = true)
#  |-- data_dwc_namePublishedIn: string (nullable = true)
#  |-- data_dwc_namePublishedInID: string (nullable = true)
#  |-- data_dwc_namePublishedInYear: string (nullable = true)
#  |-- data_dwc_nomenclaturalCode: string (nullable = true)
#  |-- data_dwc_nomenclaturalStatus: string (nullable = true)
#  |-- data_dwc_occurrenceDetails: string (nullable = true)
#  |-- data_dwc_occurrenceID: string (nullable = true)
#  |-- data_dwc_occurrenceRemarks: string (nullable = true)
#  |-- data_dwc_occurrenceStatus: string (nullable = true)
#  |-- data_dwc_order: string (nullable = true)
#  |-- data_dwc_organismID: string (nullable = true)
#  |-- data_dwc_organismName: string (nullable = true)
#  |-- data_dwc_organismQuantity: string (nullable = true)
#  |-- data_dwc_organismQuantityType: string (nullable = true)
#  |-- data_dwc_originalNameUsage: string (nullable = true)
#  |-- data_dwc_otherCatalogNumbers: string (nullable = true)
#  |-- data_dwc_ownerInstitutionCode: string (nullable = true)
#  |-- data_dwc_parentNameUsage: string (nullable = true)
#  |-- data_dwc_phylum: string (nullable = true)
#  |-- data_dwc_pointRadiusSpatialFit: string (nullable = true)
#  |-- data_dwc_preparations: string (nullable = true)
#  |-- data_dwc_previousIdentifications: string (nullable = true)
#  |-- data_dwc_recordNumber: string (nullable = true)
#  |-- data_dwc_recordedBy: string (nullable = true)
#  |-- data_dwc_reproductiveCondition: string (nullable = true)
#  |-- data_dwc_rights: string (nullable = true)
#  |-- data_dwc_rightsHolder: string (nullable = true)
#  |-- data_dwc_samplingEffort: string (nullable = true)
#  |-- data_dwc_samplingProtocol: string (nullable = true)
#  |-- data_dwc_scientificName: string (nullable = true)
#  |-- data_dwc_scientificNameAuthorship: string (nullable = true)
#  |-- data_dwc_scientificNameID: string (nullable = true)
#  |-- data_dwc_sex: string (nullable = true)
#  |-- data_dwc_specificEpithet: string (nullable = true)
#  |-- data_dwc_startDayOfYear: string (nullable = true)
#  |-- data_dwc_stateProvince: string (nullable = true)
#  |-- data_dwc_subgenus: string (nullable = true)
#  |-- data_dwc_taxonID: string (nullable = true)
#  |-- data_dwc_taxonRank: string (nullable = true)
#  |-- data_dwc_taxonRemarks: string (nullable = true)
#  |-- data_dwc_taxonomicStatus: string (nullable = true)
#  |-- data_dwc_typeStatus: string (nullable = true)
#  |-- data_dwc_verbatimCoordinateSystem: string (nullable = true)
#  |-- data_dwc_verbatimCoordinates: string (nullable = true)
#  |-- data_dwc_verbatimDepth: string (nullable = true)
#  |-- data_dwc_verbatimElevation: string (nullable = true)
#  |-- data_dwc_verbatimEventDate: string (nullable = true)
#  |-- data_dwc_verbatimLatitude: string (nullable = true)
#  |-- data_dwc_verbatimLocality: string (nullable = true)
#  |-- data_dwc_verbatimLongitude: string (nullable = true)
#  |-- data_dwc_verbatimSRS: string (nullable = true)
#  |-- data_dwc_verbatimTaxonRank: string (nullable = true)
#  |-- data_dwc_vernacularName: string (nullable = true)
#  |-- data_dwc_waterBody: string (nullable = true)
#  |-- data_dwc_year: string (nullable = true)
#  |-- data_id: string (nullable = true)
#  |-- data_idigbio_recordId: string (nullable = true)
#  |-- data_symbiota_recordEnteredBy: string (nullable = true)
#  |-- data_symbiota_verbatimScientificName: string (nullable = true)
#  |-- datasetid: string (nullable = true)
#  |-- datecollected: timestamp (nullable = true)
#  |-- datemodified: timestamp (nullable = true)
#  |-- dqs: float (nullable = true)
#  |-- earliestageorloweststage: string (nullable = true)
#  |-- earliesteonorlowesteonothem: string (nullable = true)
#  |-- earliestepochorlowestseries: string (nullable = true)
#  |-- earliesteraorlowesterathem: string (nullable = true)
#  |-- earliestperiodorlowestsystem: string (nullable = true)
#  |-- etag: string (nullable = true)
#  |-- eventdate: string (nullable = true)
#  |-- family: string (nullable = true)
#  |-- fieldnumber: string (nullable = true)
#  |-- formation: string (nullable = true)
#  |-- genus: string (nullable = true)
#  |-- geologicalcontextid: string (nullable = true)
#  |-- geopoint_lat: double (nullable = true)
#  |-- geopoint_lon: double (nullable = true)
#  |-- group: string (nullable = true)
#  |-- hasImage: boolean (nullable = true)
#  |-- hasMedia: boolean (nullable = true)
#  |-- highertaxon: string (nullable = true)
#  |-- highestbiostratigraphiczone: string (nullable = true)
#  |-- individualcount: float (nullable = true)
#  |-- infraspecificepithet: string (nullable = true)
#  |-- institutioncode: string (nullable = true)
#  |-- institutionid: string (nullable = true)
#  |-- institutionname: string (nullable = true)
#  |-- kingdom: string (nullable = true)
#  |-- latestageorhigheststage: string (nullable = true)
#  |-- latesteonorhighesteonothem: string (nullable = true)
#  |-- latestepochorhighestseries: string (nullable = true)
#  |-- latesteraorhighesterathem: string (nullable = true)
#  |-- latestperiodorhighestsystem: string (nullable = true)
#  |-- lithostratigraphicterms: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- lowestbiostratigraphiczone: string (nullable = true)
#  |-- maxdepth: float (nullable = true)
#  |-- maxelevation: float (nullable = true)
#  |-- member: string (nullable = true)
#  |-- mindepth: float (nullable = true)
#  |-- minelevation: float (nullable = true)
#  |-- municipality: string (nullable = true)
#  |-- occurrenceid: string (nullable = true)
#  |-- order: string (nullable = true)
#  |-- phylum: string (nullable = true)
#  |-- recordnumber: string (nullable = true)
#  |-- recordset: string (nullable = true)
#  |-- scientificname: string (nullable = true)
#  |-- specificepithet: string (nullable = true)
#  |-- startdayofyear: integer (nullable = true)
#  |-- stateprovince: string (nullable = true)
#  |-- taxonid: string (nullable = true)
#  |-- taxonomicstatus: string (nullable = true)
#  |-- taxonrank: string (nullable = true)
#  |-- typestatus: string (nullable = true)
#  |-- uuid: string (nullable = true)
#  |-- verbatimeventdate: string (nullable = true)
#  |-- verbatimlocality: string (nullable = true)
#  |-- version: integer (nullable = true)
#  |-- waterbody: string (nullable = true)
#  |-- op: string (nullable = true)

# %% [markdown]
# Now this should be writable as a CSV

# %%
(flat
 .write
 .format("com.databricks.spark.csv")
 .mode("overwrite")
 .option("header", "false")
 .save("/tmp/test_ee_export.csv")
)

# %% [markdown]
# Do need the header though, a separate file is acceptable for now so let's see what this makes. Can use getmerge and concatenation during publishing to combine them.

# %%
(flat
 .limit(1)
 .coalesce(1)
 .write
 .format("com.databricks.spark.csv")
 .mode("overwrite")
 .option("header", "true")
 .save("/tmp/test_ee_export_one_line.csv")
)
